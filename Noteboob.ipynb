# %% [markdown]
# # Example

# %% [markdown]
# ##### Import libraries

# %%
import snowflake.snowpark as snowpark
from snowflake.snowpark.functions import col
from snowflake.snowpark.context import get_active_session
import pandas as pd
import altair as alt

# %%
%%sql -r dataframe_1
select class_id,
class_code, 
class_name,
max_capacity
from db_module1.academic.classes

# %%
pandas_df = dataframe_1.to_pandas()

pandas_df.head()

# %%
session = get_active_session()

# %%
df = session.sql("""
    select class_id, class_code, max_capacity, credits
    from db_module1.academic.classes
    """)

# %%
df.show()
